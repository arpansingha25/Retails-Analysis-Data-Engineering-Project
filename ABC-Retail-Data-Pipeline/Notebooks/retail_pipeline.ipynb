# %% [markdown]
# # Retail Pipeline Notebook
# This notebook runs the exported pipeline script and generates the curated CSV output.

# %%
from pathlib import Path
import runpy

script_path = Path.cwd().parent / "Code" / "retail_pipeline.py"
runpy.run_path(str(script_path), run_name="__main__")
